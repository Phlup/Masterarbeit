# %%
##example notebook of genotype simulation

# %%
from project_lib.genotype_simulation import *
from project_lib.stat_functions import *

# %%
#read genetic map
genmap = pd.read_csv("data/sim_data/B73_genmap.csv")
#read parent genotypes
parent_genos = pd.read_csv("data/sim_data/NAM_parent_genos.csv")
#read reference allele
ref_allele = pd.read_csv("data/sim_data/B73_alleles.csv")
# read population names
populations = pd.read_csv("data/sim_data/populations.csv")

# %%
#data structure to capture simulation information for multiple simulations
pop_dict = dict(zip(populations["pop"], populations["name"]))
size_dict = dict(zip(populations["pop"], populations["size"]))
pops = populations["pop"]

# %%
#founders of population 1
pop_dict[1]
# Out:
# 'B73_B97'

# %%
#num offspring of population 1
size_dict[1]
# Out:
# 194

# %%
#different recombination parameterizations
genmap_high = genmap.copy()
genmap_high["Rate(cM/Mb)"] += 5
#ensure last recombination rate is 0 at every chromosome (requirement for msprime)
genmap_high.loc[genmap_high.groupby("Chromosome").tail(1).index, "Rate(cM/Mb)"] = 0
#genmap with 0 recombination rate
genmap_zero = genmap.copy()
genmap_zero["Rate(cM/Mb)"] = 0
# genmap with constant recombination rate (mean over all recombination)
genmap_mean = genmap.copy()
genmap_mean["Rate(cM/Mb)"] = genmap["Rate(cM/Mb)"].mean()
genmap_mean.loc[genmap_mean.groupby("Chromosome").tail(1).index, "Rate(cM/Mb)"] = 0

# %%
##pedigree used for genotype simulations (offspring num according to size dict)
pedigree = cross_selfing_ped(offspring = 10, selfing_genos = 5)
draw_pedigree(df_to_ts(pedigree).tree_sequence(), out_path = "plots/ARGs etc/crossself5.png")

# %%
## normal estimated recombination rate for population 1
pop = pop_dict[1].split("_")
norm_sim = genotype_simulation(genetic_map = genmap, parent_genos = parent_genos, ref_allele = ref_allele,
                                       founder_list = pop, offspring = size_dict[1], selfing_genos = 5)
# Out:
# starting simulation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## normal estimated recombination rate for population 1
#       2 pop = pop_dict[1].split("_")
# ----> 3 norm_sim = genotype_simulation(genetic_map = genmap, parent_genos = parent_genos, ref_allele = ref_allele,
#       4                                        founder_list = pop, offspring = size_dict[1], selfing_genos = 5)
#
# File ~\Masterarbeit\project_lib\genotype_simulation.py:354, in genotype_simulation(genetic_map, parent_genos, ref_allele, founder_list, offspring, selfing_genos)
#     352 chr_arg = msprime.sim_ancestry(initial_state = chr_ts, model="fixed_pedigree", recombination_rate = chr_rate_map)
#     353 #propagate ARG recombinations to offspring genotypes
# --> 354 chr_geno_sim = propagate_geno(chr_arg, founder_nodes, chr_genmap)
# ...

# %%
#simulation with zero recombination rate for population 2
pop = pop_dict[2].split("_")
zero_sim = genotype_simulation(genetic_map = genmap_zero, parent_genos = parent_genos, ref_allele = ref_allele, 
                                founder_list = pop, offspring = 10, selfing_genos = 5)

# %%
##print simulated genotypes with normal recombination params
norm_sim[0]

# %%
##print simulated genotypes with zero recombination rate
zero_sim[0]

# %%
##print ancestral recombination graph (ARG) for chr1 of norm simulation
print(norm_sim[1][0].dump_tables())

# %%
##print ancestral recombination graph (ARG) for chr1 of norm simulation
print(norm_sim[1][0].dump_tables().edges)

# %%
##draw ARG of chr1 of norm simulation
draw_ancestry(norm_sim[1][0], x_size = 1500000, y_size = 500, out_path = "plots/ARGs etc/normfullARG.svg)

# %%
##print ancestral recombination graph (ARG) for chr1 of zero recombination simulation
print(zero_sim[1][0].dump_tables())

# %%
##draw ARG of chr1 of zero recombination simulation
draw_ancestry(zero_sim[1][0], x_size = 1400)

# %%
#calc recombination statistics (avg. recombination block length + total blocks per individual in offspring generation)
calc_total_recomb(norm_sim[1])

# %%
calc_total_recomb(zero_sim[1])
